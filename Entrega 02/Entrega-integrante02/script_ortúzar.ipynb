# %%
import pandas as pd

# %%
# !ls
# Out:
# 'base de datos general(Hoja1).csv'   sample_data

# %%
import seaborn as sns # importar la libreria seaborn

# %%
olimpicos = pd.read_csv('base de datos general(Hoja1).csv')
olimpicos.head()
# Out:
#     JJOO   AÑO             DEPORTE          DISCIPLINA             CATEGORÍA  \
# 0  París  2024              Fútbol              Fútbol  Femenino y Masculino
# 1  París  2024           Atletismo           Atletismo  Femenino y Masculino
# 2  París  2024  Deportes Acuáticos           Waterpolo  Femenino y Masculino
# 3  París  2024  Deportes Acuáticos  Natación Artística              Femenino
# 4  París  2024  Deportes Acuáticos           Natación   Femenino y Masculino
#
#    N° MUJERES  N° HOMBRES  MEDALLA
# 0         216          288      Sí
# 1         905          905      Sí
# 2         110          135      Sí
# 3          99            0      Sí
# 4         426          426      Sí
