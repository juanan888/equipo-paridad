# %%
import pandas as pd

# Cargar la base de datos limpia
df = pd.read_csv('base_datos_historica_JJOO_1900_1936.csv')
# Visualizar las primeras filas
df.head()
# Out:
#      JJOO   AÑO             DEPORTE                 DISCIPLINA  CATEGORÍA  \
# 0  Berlín  1936           Atletismo                       100m   Femenino
# 1  Berlín  1936           Atletismo                       100m  Masculino
# 2  Berlín  1936  Deportes Acuáticos       Natación 100m libres   Femenino
# 3  Berlín  1936  Deportes Acuáticos       Natación 100m libres  Masculino
# 4  Berlín  1936            Gimnasia  Gimnasia Artística Equipo   Femenino
#
#    N° MUJERES  N° HOMBRES MEDALLA
# 0          30           0      SI
# 1           0          63      SI
# 2          33           0      SI
# 3           0          45      SI
# 4          64           0      SI
